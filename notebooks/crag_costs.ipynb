# %%
from neuralimg.crag import crag_utils as cu
crag_path = '/DataDisk/morad/test/sampleB/hdf/training_dataset.h5'
costs = cu.CragCostManager(crag_path)
# Out:
# No node features found. Creating from scratch ...
# No edge features found. Creating from scratch ...
# No features weights found. Creating from scratch ...

# %%
# Read from crag - If crated from scratch, they are empty lists
merge, weights = costs.get_node_weights()
edge = costs.get_edge_weights()
mergef = [i for i in merge]
weightsf = [i for i in weights]
edgef = [i for i in edge]

# %%
print(edgef)
# Out:
# []

# %%
print(weightsf)
# Out:
# [4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0]

# %%
# Modify and read again (above) to see if content changed
costs.update_node_weights(5, [4] * 109)
costs.update_edge_weights(9)
# Out:
# Updating slice node weights with ones according to feature size of 109

# %%
# Save into crag, and then repeat whole process from beginning to see if they changed
costs.save()
# Out:
# Saving node features ---
# Saving edge features ...
# Saving feature weights ...

# %%
# Feature save process
costs.update_node_features('/DataDisk/morad/networks/alexnet4_d05_1e-3reg_1e-3lr/models')
# Out:
# Found %d assignment nodes 51552
# Step 0 (0-256)
# Building images for node 0 in the batch
# Building images for node 1 in the batch
# Building images for node 2 in the batch
# Building images for node 3 in the batch
# Building images for node 4 in the batch
# Building images for node 5 in the batch
# Building images for node 6 in the batch
# Building images for node 7 in the batch
# Building images for node 8 in the batch
# Building images for node 9 in the batch
# Building images for node 10 in the batch
# Building images for node 11 in the batch
# Building images for node 12 in the batch
# Building images for node 13 in the batch
# Building images for node 14 in the batch
# Building images for node 15 in the batch
# Building images for node 16 in the batch
# Building images for node 17 in the batch
# Building images for node 18 in the batch
# Building images for node 19 in the batch
# Building images for node 20 in the batch
# Building images for node 21 in the batch
# ...

# %%
costs.save()
